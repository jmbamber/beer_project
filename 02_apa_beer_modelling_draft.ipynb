# %% [markdown]
# # Beer draft modelling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from tqdm import tqdm_notebook
import random as random

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
from sklearn.model_selection import cross_val_score, train_test_split, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report, precision_recall_curve, r2_score, mean_squared_error
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
from my_classes import Dropper, Dummier, Vectorizer, Stemmer

# %%
apa_df = pd.read_csv("./data/reviews/apa_cleaned.csv")

# %%
apa_df.head()
# Out:
#    rating  look  smell  taste  feel  overall  \
# 0    3.62  4.25   3.50   3.50  3.75     3.75
# 1    4.06  4.00   4.25   4.00  4.00     4.00
# 2    3.93  3.75   3.75   4.00  4.00     4.00
# 3    4.35  4.00   4.00   4.75  4.00     4.25
# 4    3.27  3.50   3.25   3.25  3.25     3.25
#
#                                               review        date    id  \
# 0  From notes 3/31/13: Pours clear medium amber p...  2019-01-04  1157
# 1  It's funny that the best English Bitter that I...  2018-12-17  1157
# 2  12oz bottle dated 21SEP18 poured into my mouth...  2018-12-14  1157
# 3  Had this on tap when we went for dinner. I was...  2018-08-19  1157
# 4  As a fan of their IPA thought I would give Hon...  2018-08-18  1157
#
#            name
# 0  Honker's Ale
# 1  Honker's Ale
# 2  Honker's Ale
# 3  Honker's Ale
# 4  Honker's Ale

# %%
apa_df.describe()
# Out:
#              rating          look         smell         taste          feel  \
# count  17349.000000  17349.000000  17349.000000  17349.000000  17349.000000
# mean       3.847477      3.914798      3.806233      3.848252      3.843569
# std        0.507472      0.500440      0.570200      0.577121      0.540289
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.570000      3.500000      3.500000      3.500000      3.500000
# 50%        3.900000      4.000000      4.000000      4.000000      4.000000
# 75%        4.190000      4.250000      4.250000      4.250000      4.250000
# max        5.000000      5.000000      5.000000      5.000000      5.000000
#
#             overall             id
# count  17349.000000   17349.000000
# mean       3.869291   68297.891982
# std        0.541931   63931.274590
# min        1.000000      39.000000
# 25%        3.500000   10365.000000
# 50%        4.000000   59192.000000
# 75%        4.250000   91566.000000
# max        5.000000  315536.000000

# %%
#setting my binary rating at about the median
apa_df["rating_bin"] = apa_df["rating"].apply(lambda x: 1 if x > 3.9 else 0)

# %% [markdown]
# ### Baseline

# %%
#checking baseline accuracy
baseline = apa_df["rating_bin"].value_counts(normalize=True).max()
baseline
# Out:
# 0.5068303648625281

# %% [markdown]
# ### Logistic

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs")

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
log_pipe.fit(X_train, y_train)
scores = cross_val_score(log_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.772
# CV std = 0.009
#
# Test score: 0.776

# %%
log_coeffs = pd.DataFrame(zip(log_pipe.steps[1][1].feature_names, log_pipe.steps[2][1].coef_[0]), columns = ["feature", "coeff"])
log_coeffs.sort_values("coeff", ascending=False).head(15)
# Out:
#          feature     coeff
# 8224       great  4.763636
# 5162   delicious  4.697484
# 6659   excellent  4.184421
# 6923   fantastic  3.939213
# 13146    perfect  3.925794
# 9898       juicy  3.625156
# 1922   beautiful  3.211588
# 10963      mango  3.100806
# 19832  wonderful  3.090032
# 1639     awesome  2.967771
# 10745       love  2.844618
# 1728    balanced  2.759762
# 4930        dank  2.742417
# 17805      tasty  2.706056
# 8310     growler  2.698841

# %%
for i in range(0,apa_df["review"].str.contains("dank").sum()):
    print(apa_df[apa_df["review"].str.contains("dank")].iloc[i,0])
    print(apa_df[apa_df["review"].str.contains("dank")].iloc[i,6])
    print("")
# Out:
# 4.04
# Waited to try this beer for years and then kind of forgot about it. Suddenly it appears on local shelves. It is pretty good for only having the terrible Citra hop being used (I am sorry but Psuedo Sue is terrible). I would describe this as the original juicy pale ale before the haze craze came along. It also has the benefit of having bitterness and not being overly sweet. Would I drink this regularly? Probably not as I am more in the pine, herbal, earthy, dank spectrum with hoppy beers.
#
# 4.33
# Appearance: Pours a glowing, but not bright,orange/amber color like an ember from a dying campfire. Aroma: Strong citrus aroma of mandarin orange, ripe pineapple, grapefruit. A dank pine forest. Flavor: Tons of nice mandarin orange, grapefruit, ripe pinapple with a dank and resiny pine flavor. A somewhat sweeter honey (maybe toffee?) bread malt body follows. A wave of bitterness finishes on the end.  Feel: Medium body, but a heavier mouthfeel. It captures the IPA level of hop flavor bitter astringency on the tongue, but follow with the perfect amount of malt sweetness to leave you wondering whether it's bitter, sweet, or both. Overall, though its dry on the tongue.  Compared to PsuedoSue: This one has a darker amber color. It has more dank and earthy notes. Not as airy. Less piney. A stronger bitterness. Much heavier bodied and more resiny. Not quite as smooth. Leans more toward an IPA. Overall: An top shelf beer. I was initially blown away by the bitterness on the nose, yet when tasted it has such a strong malt balance to counteract that. It's the perfect balanced pale ale here and I'm not sure whether it finishes bitter or sweet. I think that's what makes it finish so well and would rate this pale ale as a top not because of that. I think it pioneered the style of west-coast IPA,
#
# 4.08
# 12oz bottle. 4/30/19 bottle date. Appearance: Dark golden orange, cloudy, with a fluffy white foam head and decent lacing.  Aroma: Dank, super resinous, and grassy, with a touch of citrus rind  Taste: Moderate malt sweetness, mostly caramel but also with a touch of cracker. A sharp bitterness rises with only.a hint of citrus and resin Mouthfeel: Medium bodied with carbonation on the Light side Finish: Dry and resinous in the tongue. Strong residual bitterness leads over malt, building intensity after the swallow.  Overall: Prototype for an original American Pale Ale/IPA. The bitterness and malt character seem on the strong end for an APA. Definitely has a stronger malt base reflective of the traditional style as opposed to the newer evolution of the style. Clean and crisp with a nice dank and resinous hop character
#
# 4.5
# So, let's dispense with the BS that this is an APA - it's an IPA - and a damn good one! Pours a light copper with over a finger of head. The nose is piney with dank notes as well. The flavor profile has a strong malt backbone with hoppy bitterness that is amped up to a Spinal Tap 11. Nice and resiny too. The real magic of this offering is that it is only 6.2% but it has the bold flavor of an 8-10% DIPA. I only wish that it were more readily available here in Eastern PA.
#
# 4.6
# This pale ale pours a dark, burnt amber color with modest finger and a half of soapy, rocky head that quick dissipates. The smell is a potpourri of floral notes, as well as citrus from tangerine and an orange juice quality to grapefruit and pineapple with a hint of papaya and mango. A touch of pine on the nose from the Citra hops, as well as a malty, cake batter or light vanilla sweetness to it. Up front, it’s earth and green with a mild hop dankness to it. The beer opens up with bready and caramel body with a slight tropical fruit note of pineapple and mango. Zombie Dust has a clean and crisp mouthfeel to it, with a resiny and bitter, but dry finish to it. Could drink this beer all day long.
#
# 4.29
# Definitely a beer I would like to have regular access to, but alas, I snagged this bottle on a trip to Cincinnati. Poured from a bottle into a tulip glass. Golden yellow color with a great head and nice lacing. Citrus and herbal smell and taste. Sort of a dank background flavor I cannot identify. A bit peppery. Great beer!
#
# 4.66
# Looks- It looks like beer. Good lacing. Pretty head Nose- It smells like a good beer. Not to danky. Just right
#
# 4.96
# Really grateful to FBarber for hooking me up with this highly acclaimed beer via trade. I had it once on tap as a nightcap. Let’s see what it tastes like on a fresh palate. Pours an amber color with an orange hue. light haze and moderate head that displays good retention. It’s not the most special looking beer ever, but the appearance does hint at a solid body. The aroma opens with a delicious burst of citrus and tropical fruit. Notes of tangerine, freshly squeezed orange juice, grapefruit, pineapple, mango, papaya and even a hint of banana. Aromas of caramel malt foresee a solid malt base to come. Amidst all of this, a wonderful pungent layer of herbal aromas, pine, grass and dank, delight the nose. From the start, the taste opens up with earthy hops flavors, piny, resiny and dank. The palate opens dry with a significant yet clean bitterness. Flavors begin to open up, particularly the interplay between malts and hops. A firm bready and caramel malt backbone adds body, roundness and moderate sweetness. A juicy burst of citrus fruit, grapefruit rind, orange pith, and a touch of lemon fills the palate. Also, notes of tropical fruit, pineapple and mango compliment the malts and other hops flavors. Delightfully sublime taste overall, supremely balanced and dynamic. Medium bodied, moderately carbonated and smooth overall. Resiny, bitter and dry finish begs for more sips. I could crush multiple bottles. This beer is a true work of art. Finely crafted and supremely balanced. I don’t buy into all of this nonsense that its time has come and that newer beer trends have surpassed it. This magical elixir is, simply put, a delicious classic that has the ability to stand the test of time and outlast passing fads. Well worth the hype!
#
# 4.43
# Appearane-The beer pours a nice orange-amber color that has a little bit of haze and a one finger head of pure white foam. The head fades fairly fast leaving a light level of foamy lace on the sides of the glass. Smell- The aroma is heaviest of citrus hops of tangerine and orange and has lots of tropical fruit aromas that blend with the citrus nicely. Along with these smells are other hop notes of earth and a light herb. Some bread and caramel are in there as well and produce a fruity and inviting aroma overall. Taste- The taste begins sweet and malty with lots of dough and a ton of fruit, with tangerine, orange, pinapple, mango, and papya all there. The hop is mainly of a citrus nature upfront, which while initially somewhat light, grows stronger as the taste advances. Along with the increase in citrus hop, so to comes other more dank hop tastes of pine and earth. With a bit of a surge of sweet, as a modest candied sugar taste and more fruit come at the very end, one is left with a sweet and malty but nicely citrus and moderately dank hopped flavor to linger on the tongue. Mouthfeel- The body of the brew is thick and chewy with a carbonation level that is moderate. For the mix of sweet, hop, and fruity malt the feel is great and makes a great drinker. Overall- A very tasty beer!! It has a great drinkability with tons of fruity flavor and a very enjoyable hop blend. I can see why this beer has a good reputation and is one to try if you get a chance.
#
# 4.35
# *The quality of this beer can vary a good deal batch to batch. Three Floyds Zombie Dust Pale Ale - 6.2% ABV - 50 IBUs Date: 08/01/18, consumed on 08/27/18. Appearance: Murky burnt orange with a finger of sudsy eggshell colored head. The head retention is better than most Pale Ales, it really sticks around.  Aroma: Grapefruit and tons of it, pine, and orange aromas dominate but the malts are more assertive as well, presenting a light bread crust like backbone.  I am also getting faint hints of like mango in syrup. Some dank resinous aroma comes through as well, although it isn’t anything overwhelming. In short, this smells very nice, very aromatic with a bright citrusy hop aroma.  Taste: Right off the bat, you get a big blast of grapefruit that washes over the palate. The other thing that is immediately noticeable is that Zombie Dust drinks fairly bitter for being a 50 IBU pale ale. The malts here have a bit of that sweeter syrup quality to them rather than the bread like notes of the nose. It's not unlike a malt profile of say, an 8% beer with 80 IBUs. Having said that, Zombie Dust is very drinkable, not too heavy or reliant on the malts in the least. For as bold and out of balance as this one might sound, the opposite is actually true. Much like the balance of aromas, Zombie Dust achieves a almost absurdly balanced taste as well. For me, this one skirts the line between a pale ale and an IPA. At times it seems like an 8% IPA flavor wise, yet it's so easy drinking that most would be able to session two or three of these without issue. As the beer warms, some of that sweet mango and tangerine flavors come to the forefront. It is a really nice flavorful beer and worth the $13 price tag.  Biased comments: Zombie Dust is a really nice beer, but I feel the reputation it has is somewhat overinflated. I happily admit that it is the best and most flavorful lower ABV pale ale I have had and those seeking a more grapefruit forward pale ale or lighter end IPA should look no further. However, considering the hoops often required just to get a six pack, Zombie Dust, for me, often falls in favor of shelf beers like Alpha King or a Stone Brewing IPA.
#
# 4.14
# Two plus finger head of light tan to cream white, extremely thick and barely moves for some time, the lacing slowly tears off from the head, more random splotches than streaks. Dark bronze orange colored liquid, faint haze, the bubbles are tiny but swirl upwards with rapidity. Malts ground the nose with mocha, dark chocolate to challah bread notes, then spiced oranges, pine cone, tarry earth and just cut onions, leafy dankness, oddly the papaya, nectarine, pear scents never really factor in and it might be easy to not even notice this element. Full-bodied, creamy texture, fills the mouth from cheek to cheek, borderline heavy. The carbonation is a little better than average but not especially refreshing. Loaded with honeyed tangerine to grapefruit citrus as well as sticky pine sap, in turn the Saltine cracker and charred pizza crust notes substantial. Malted milk balls, bitter chocolate with less intense caramel. Much more floral at the finish and retronasally. The apricot, peach, pineapple, pear fruit remains lowkey but consistent in that. Smooth for its weight and the relatively low ABV helps drinkability. Worth seeking out.
#
# 4.4
# Six from Whole Foods - bottled July 2/18 - 3 weeks old. Pours a just short of clear golden orange with off white head. Aroma is fantastic dank citrus verging to sweaty onion. Taste is hop forward on the citra - grapefruit, pine, but some bready malt sweetness. Bitter finish with medium full body - bitterness lingers nicely, but the aroma keeps me coming back for more. Absolutely love this beer.
#
# 4.33
# This is a really good, really drinkable, and really hoppy American Pale Ale (which most people would consider an IPA). Pours a light, clear orange gold with a smattering of lacing that persists. Good level of carbonation. Smell is dank, oniony mixed with ripe melon. Hints of cracker and bread malt and yeast aroma as well. Taste is wonderfully hop-forward with great depth of bitterness and flavor from the Citra. I pick up hints of pine and citrus, but mostly ripe tropical fruit in the taste. Malt is there but takes a backseat to the hop show. This is a really nice pale ale and would love to have it more often.
#
# 4.37
# Beautiful, slightly opaque light-copper body. Huge, fluffy, eggshell head that holds up well and leaves ring upon ring of sticky, sudsy lacing. Lemon, lemongrass, pine sap, dish soap, light biscuit, and dank hay on the nose. Maybe a little tropical citrus, some herbal greens, and a pilsner malt-like note in the background. Taste is bright, bitter citrus pith balanced by a wave of semi-dry fruit sweetness. Lots of lemon, grapefruit, berry, white grape, and resin. Crackery malt with a touch of salt. Dry, white wine finish with a wonderful, lingering grapefruit bitterness aftertaste. Unbelievably drinkable. Soft, well-carbonated, silky feel. Hefty body than you'd expect on a 6% beer, but certainly not sticky or heavy. Nice coating quality that helps that grapefruit pith finish last even longer.
#
# 4.75
# Pouring from a 12 oz. can into a snifter glass, this beer pours out golden and honey in color while forming a perfect pinky width off off yellow colored dense and creamy crown. Not see through but not hazy.  The smell is dank with citrus, pine, resin. Dank.  The taste brings the pine to the front and translations into some stone fruit. Dank.  The mouthfeel is light, perfect for the summer. Not too thick or cloying for the style. Sticky.  Overall, I honestly think this is still the best citra exclusive pale ale. Convince me otherwise.
#
# 4.54
# Courtesy of @FFFjunkie. Bottled 9/11/2017 and poured into 3 Floyds pint glass. It pours a hazy, orange-amber with a finger plus of fluffy, ecru-colored head that resembles gelato, and thick, elegant lacing that never dissipated. It's a beautiful pour. The nose is primarily malty with lemon peel, grapefruit, lots of pine, and aromatic hops. It's dank and decidedly bitter with abundant biting Citra hops but there's also a noticeable flavor of sweet malt and there is also subtle lemon and pineapple, particularly as the glass warms. It finishes with pepper notes. For an APA, it has a creamy, viscous mouth feel with lively carbonation. And with a temperate ABV of 6.2%, it's a very easy drinker. Overall, Zombie Dust is simply an exquisite Pale Ale; one of the best I've ever had. And it's a nice throwback inasmuch as it doesn't rely on a lot of tropical fruit. This is brewing at its best! I checked and it's my highest-rated APA. Which says a lot since Sneak Box is outstanding.
#
# 4.37
# Opens with pine, grass, and dank hop aromas. Flavor is fruity and juicy with a note of pine. It has moderately high bitterness and a smooth finish that is both malty and bitter. There is a clean, sweet malt backbone that makes this beer very balanced between malt and hops.
#
# 4.34
# Bottled 16 days ago and had alongside a 3.5-week-old can of PseudoSue. L -- Pours a pale golden color with the slightest bit of haze and a 2-finger head produced with moderately aerated pour. Some retention and good lacing. S -- Pineapple, earth, candied grapefruit, papaya, mango, cannabis, and a hint of that rubber hops smell too T -- Big earthy and grassy flavors upfront, rounded out by cracker malts and hints of tropical fruit and dank pine resin F -- Nice, well-rounded mouthfeel, especially given the fairly low ABV. Crisp and refreshing. Medium carb and medium mouthfeel. Finishes dry with a restrained bitterness O -- My main complaint with this and all other citra-centric beers I've had is that the aromas and flavors are heavy on the grassy/earthy characteristics. I'm personally more of a fruit-forward hop guy (galaxy and mosaic topping my list), and I think I subconsciously equate any sort of harsh grassiness with 'old'. Still, this is an absolute joy to drink and I'm glad to have located a bottle during a five hour train layover in Chicago 87/100
#
# 4.34
# Look - a slightly opaque golden orange with a one-finger white head that sticks around and has decent lacing throughout. Smell - dank pungent hops are front and center, but you also get a nice array of hop aromas in the form of citrus (grapefruit, lemon, orange) and floral notes. There are also some sweet notes lingering in the background that might be caramel malts. Taste - very similar to the nose in that dank resin, earthy hops are very powerful, but it's balanced with the lighter side of the hop spectrum since the citrus and floral notes (like mentioned above) shine through. Again, there's a slight malty presence in the form of caramel and bread, but these notes are almost completely overpowered by the thick hop characteristics.  Feel - high carbonation, medium body, sticky mouthfeel. Overall, this is definitely an interesting example of the style. It tastes more like an imperial IPA, but it still maintains aspects of a lighter, refreshing pale ale. It's a hop bomb for sure, which isn't exactly my thing anymore, but I would absolutely jump at the chance to have this again.
#
# 4.27
# L: copper orange, clear, 1-finger cream head S: subtle orange, caramel, slightly dank hop aroma T: sweet caramel malt, orange, grapefruit, plum, herbal hop bitterness on the back end  M: medium with clean finish  O: a tasty and refreshing Pale Ale with pleasing complexity
#
# 4.22
# 19.2 oz. canned on 03/18/16 Pours clear burnt amber orange with a creamy frothy off-white foam head. Smells like sweet dark malt, toasty, bready, biscuity, crackery, with some floral grass, mild pine, melon, and orange grapefruit citrus. Tastes like burnt toasty bready grains, biscuity caramely cracker, dank pine and earthy floral grass, mild melon, with some orange and grapefruit citrus. Feels medium bodied, creamy with moderate low carbonation. Overall a nice malty pale ale.
#
# 4.0
# Red-amber in color, with very good clarity. Topped with a pale tan head. Good lacing and duration. Resiny hop character up front on the nose, this beer is part old school Microbrew tradition of the West Coast style and part new school innovation, with a good mess of different hops used. Not quite “dank”, but flowery and herbal (more on that in the taste). Clean ale character and some biscuit malt on the nose. On the first sip it’s sweet, smooth, slightly sharp and tangy. Bitterness is restrained but sturdy; This used to be one of the most bitter U.S. ales in the pale ale -to- IPA range, but was eclipsed over the past twentysomething years. Bitterness lingers and blends with a bittersweet undertone, along with very prominent herbal character. The one herbal note I’m getting now (and bear in mind that I haven’t enjoyed this regularly in close to twenty years) is of damiana, or diviner’s sage. If you’ve never partaken of damiana, it’s a pungent and sweet herb, and though I doubt that FFF would’ve ever brewed with it, maybe they did partake? An interesting note at any rate, and adds depth of flavor to the ale. Good drinkability, albeit a bit fuller in flavor and character than a good many lower strength examples in the very broad American Pale Ale style. A very, very good beer overall. Canned 6/19/19 — less than three weeks ago.
#
# 3.78
# 12 oz bottle poured into a pub-style pint. Appearance Deep amber; almost copper. 2 fingers of tan head. Hazy with moderate carbonation. Nose Grapefruit, lemon, pine, and caramel. Taste Grapefruit, lemon zest, and pine. Firm caramel maltiness. Slight touch of dankness. Mouthfeel Medium bodied, smooth, creamy, silky, and lightly bitter. Overall For such an old style Pale Ale, it's incredibly drinkable for near 7%.
#
# 4.44
# Appearance: Pours a hazy, pure copper color with a foamy, and lacy head that lingers. Aroma: Strong aromas of citrus, tropical melon and stonefruit. A typical newer American simcoe or mosaic hop profile Flavor: Taste follows the nose. Strong flavors of citrus, tropical melon, stonefruit. This is followed by a strong hop bitterness to round out the flavor. Yet, not enough to completely clean the strong bready and slightly caramel malty sweetness that comes through underneath at the end. Finishes neither sweet nor dry. The perfect touch at the end. Finish: Moderate carbonation. Heavily bodied. Strong malt sweetness to balance the bitterness that comes through at the end. Finishes perfectly smooth.  Compared to the old-school Sierra Nevada Pale Ale: This one has more new-age American hops. Centennial and Warrier. Pungent and dank tropical melon are present. Less grapefruit and pine. Strongly bitter like an IPA, yet it finishes with a sweet bread and slightly caramel malt profile that stands up to the bitterness to define the pale ale name. Overall: This represents the new American standard of a pale ale. Newer-age American hops profile. Much more robust. Balanced perfectly with the malts. You think you're drinking an IPA, but then the sweeter malts come through for such a nice finish. The best classification of new-American hops I can think of. The citrus and tropical flavors are so strong and wonderful. I understand why you wouldn't pick a favorite beer after this one. This is a top notch quality beer.
#
# 4.58
# A - Pours a nice amber/golden color with a nice white head. S - Great citrus and hop notes. Maybe some pineyness in there. T - Excellent blend of pine/orange/dankness/hops. M - Light/medium bodied, aftertaste was excellent with lasting hops/citrus flavor. O - Excellent execution of an APA, but the stand-out aspect for me was the citrus profile. This was hands-down the best orange/citrus flavor that I've ever tasted in a beer. Most PA's have a (IMHO) fatal flaw in the citrus profile where it is either too bitter/sweet/distorted/muted/sour to rank high on my list. This may not make it fantastic for others, but in my book it makes it shine. Buy more (and more) for sure.
#
# 4.38
# Poured from a 12 oz. bottle into a pint glass.  Dark gold in color with some orange hue. The crown is a light golden color and about half a finger worth.  The smell is dank and malty. It's got a sweetness to it.  The taste is amazing. Lightly dank with a very nice malt backbone that is sweet almost like honey.  Mouthfeel is wet and sticky.  Overall, this has always been a classic to me.
#
# 4.0
# A very good IPA from a very good brewery. This beer pours a dark amber with a thin white head and some lacing. The nose comes across as fruity, tropical, and maybe sweet---but in a bubblegum kind of way---combined with some very faint dankness. The flavor is remarkable in balance---it's bitter, tart, and malty all in equal measure. There's an alcohol bite at the end, that kind of unfolds across the palate. All told, a superior contribution to the IPA canon.
#
# 4.27
# Poured Alpha King into a Belgian Tulip. A - Pours a light amber with a finger and a half of off white head. S - Grapefruit, pineapple, and citrus on first sniff. I'm also getting some light coconut with dank hops. T - The flavor mimics the aroma. Tasty stuff here! More hops, pineapple, citrus and a touch of coconut. M - Medium carbonation with medium to full mouthfeel. O - A Pale ale thats on steroids. Delicious!
#
# 4.27
# 12 ounce bottle into a tulip glass. Bottled 1/20/17, had 2/5/17. Pours an amber/orange, hazy, with an inch and a half foamy head, a good amount of foamy lacing. Lots of citrus in the smell- orange, grapefruit, lemon, hint of lime, pine, some yeast, malt, a light dankness. The taste also starts with big citrus- orange, grapefruit, lime, lemon, malt, pine- especially on the finish. A good amount of hop bitterness up front, the malt tames it thereafter. A light sweetness overall. Smooth, a solid medium body, well carbonated.  Very good citrus aroma and flavor. Well balanced between the hops and malt, really feels more like a DIPA. Pretty straightforward. but really well executed. Well worth a purchase.
#
# 4.04
# From a 12oz bottle, dated 12/02/16. Served in a tulip. Pours a semi-opaque burnt orange with a finger-plus of dense ivory head. Retention is good for a minute or so before settling back to thick, bubbly ring with loose sheets of lacing. The nose starts massively hoppy, sharp and peppery, fading off into prominent peach and sweet caramel. Taste is straight-on malt forward, sweet toasted grains and caramelized corn syrup. Bitterness is low, some spruce and citrus pith, some bubblegum, a little black pepper. Finishes with grand marnier, slightly dank and sticky. Feel is medium bodied, thick, chewy and mouth-coating, with just better than adequate carbonation. Overall, a better-than-decent APA.
#
# 4.5
# A - copper clear beer, white head sticks and leaves okay lacing S - big gummy bear, fruit punch, pomegranate; some dank resin, piney hops in the background T - big grapefruit, peach, pine, hop resin, fruit punch, gummy bear M - light, alcohol is covered, aftertaste is grapefruit and gummy bears O - great beer, unique, I'm not sure how they get that candy sweetness in there, it's not cloying at all, just tastes like eating gummy bears
#
# 4.4
# Murky creamsicle orange in color. Poured with a short, soapy white foam with medium low retention. Sharo citrus tangerine and under ripe pineapple with a light dankness. Medium malty aromas. Medium bodied with medium light carbonation. Creamy rich, silky smooth feel followed by boozy warmth that gets a little prickly at the finish. Citrus and pineapple hop flavors with a solid malt backbone. Spicy bitterness slowly expands through the middle. Pine hop and sharp citrus notes on the backend along with fruity flavors and boozy warmth. Finished semi-dryly with light fruity notes and lingering pine hop bitterness. Light fruity notes and malt provide just enough balance with fantastic, fresh, complex hop character. Smooth, creamy feel with pleasant bitterness and just a touch of dankness. This was excellent.
#
# 4.25
# 16oz can into a pint glass. Canned 8/23/19, so 6 weeks old. Thick, murky orange juice colored body with a big bubbly white head leaving nice lacing. Good aroma of non citrus fruit. Multilayered hop bite with light fruit washes. Bitterness and hoppiness fade in and out during the drink. It's a touch dank. A tasty drink, much more bitter than sweet. Mouth between medium and full. Finish on the bitter side. Overall, a good old tasty APA, pushing into IPA territory. The 6.8abv is quite apparently. Good to have Toppling Goliath making its way into PA.
#
# 4.62
# One of the truly special Pale Ales put there. Incredible aromas - citrus, and dank outdoors. Extremely refreshing flavor, with a solid level of dryness in the finish.  Not sure I would’ve pulled this one out of the cooler had it not been for BA... but worth the $5.50 price for the 16oz can!
#
# 4.54
# 16 oz can poured into an imperial shaker. Appearance Hazed-out, cloudy blonde. 1 finger of creamy white head. Nose Mango, dank, passion fruit, pine, candy sugar, and honey. Very aromatic! Taste Mango chunks, candied orange, passion fruit, and lemon zest. Moderately dank with touches of pine. Smooth and balanced backbone of honey and candy sugar. Mouthfeel Medium-plus bodied, smooth, juicy, and lightly bitter. Overall An artfully balanced and intensely flavorful Pale Ale. I get so goddamned sick of the Citra hop, but then you have something like this that makes you realize how it can be done so right.
#
# 4.02
# Golden-orange, pure juice body, medium haze, more of a covering film than head, and almost no lacing. Fruit juice all the way. Aromas are really wonderful, with huge citrus and big tropical fruit, but not the overripe, overly sweet kind. Grassy, but not overly so, with a little pine and some nice white wine notes. Really well done. Flavors are a bit of a watered down version of the above. Citrus, slightly underripe tropical fruit, light berry, very grassy, little bit of dankness, and a strong mineral note. Quite good, but a bit of a let down after the nose. Bit thin, feel-wise. Quite silky and smooth, but the body is just a touch watery. Honestly not sure how this is an APA versus an IPA, but whatever. It’s very, very good — but not exceptional— either way.
#
# 4.18
# 16 oz can. Canned on date of 5/09/19. BB date of 9/06/19. Pours a straw, hazy yellow with a soapy white head. Nose is fruity, hoppy, floral, sweetness, some hoppy notes, and a little bit of dankness. Taste is sweet. More citrus than anything but you do get some tropical fruit and that floral and herbal note. Good bitterness and works well with the pithy grapefruit you get also. Well carbonated with a light mouth feel, finishing on the dry side. This was more like an IPA. Not a Pale Ale. The flavors are a bit subdued, but deceptively so. It'll grow on you the longer you sip and savor. Very well balanced. Not as refreshing as a Dales Pale, or SN's Pale Ale, but it's a great beer which I think has been mis termed as a pale ale. It's not really in that style. Glad to start seeing TG's beers on the shelves here in NYS. Will try their other offerings and would like to try this on tap.
#
# 4.42
# Look: Pours a hazy pale orange color with a massive, foamy head that lingers. Looks like a NEIPA. Aroma: Strong aromas of citrus. Mostly unripened pineapple, peach, and pine. Lemon, mango, &amp; grapefruit are there for support. It's not quite your airy NEIPA because it has a hint of herbs and tropical dankness. Little to no earthiness. It's bitter unripened pineapple in a pine forest. Flavor: The flavor follows those nose. Slightly sweeter, but still the pineapple, peach, lemon and grapefruit. Also some mild herbal quality clove, banana, or onion. A pale malt sweetness follows the citrus for a nice finish. A mild lingering bitterness on the tongue. Body: Medium bodied and well carbonated. Feels light and crisp though. Just enough body and sweetness to satisfy, but incredibly smooth. First it's so light you think it's going to finish like juice, but then has just enough carbonation and malt to create a pillowy and light smoothness that you hardly know it's there. Compared to Zombie Dust: This is lighter colored and bodied. It has a much more light citrus, pine, and herbal quality. More pine flavor but less bitter. Lighter bodied and more balanced in terms of herbs, citrus, and pine. Really well-rounded. Overall: A very east-coast style citra-dry hopped pale ale. Delicious. Drinks like juice, but has just enough hop bitterness and body to be so much more. This is the NEIPA before there was a NEIPA. Of the Zombie Dust, Surley X-tra Citra, and this, this one is my choice. The balance and smoothness is unmatchable.
#
# 4.46
# The first thing that hits me is the heavy head with a light pour. Golden straw haze, solid lacing and displayed evenly. Immensely enjoyable interpretation of a great citrus/fruit forward IPA. Not west coast, not NEIPA, but original and well developed beer. L: Hazy S: Grassy and pine notes with big citrus. The pine has a bit more depth with additional spice notes, some doughy lingering sweetness.  T: fruit forward but more development. There is an even balance of the ingredients. Hoppy notes of citrus an slightly danky pine, with dough and malt note rounding the experience.  F: This might be my favorite part. This just sits well. Not overwhelming,not light, just a pleasant warming feeling of excellence.  O: Just an amazing well developed great beer. Development comes from experience and a real love for attention to details. When you drink this there is a feeling that the brewer drinks his own beer and judges himself with every cycle.
#
# 4.59
# Cloudy, milky orange with lots of fine bubbled carbonation, and a well sustained finger of white, fluffy head. Smells of oranges and dank leaf. Hints of catnip and mango, as well as canned peaches. Peaches, oranges and mango. Very light and delicate, and dessert like, with an orange rind bitterness on the finish. Medium, smooth, silky and fluffy body with moderate to low carbonation. Got this on in Sacramento, drinking in Redding, Dec 7th, 2018. Superb look, taste and mouth feel.
#
# 4.41
# Hazy amber orange color with a thick two finger head with good retention and leaving some laces. Superb hoppy aroma with notes of mango, lychees, fresh orange-lemon zest, clean pine, grapefruit, pineapple, flowers and bread. I am hungry, so more nose sensitive and easier to imagine this fresher. Flavor with notes of green tea, lemongrass, a bit of mango, ginger, pine, white pepper, sweet flowers, grapefruit, lemon and tangerines. Dry aftertaste with a very delimited bitterness. Light body with perfect carbonation of the tiniest bubbles given a somewhat velvet feeling. Relatively potent at 6.8% abv for and APA which is completely absent. World class APA with lots of dank and green diversity side by side zesty citrus notes. Clean and crisp as it can be. I was expecting a high bar which was delivered accordingly.
#
# 4.23
# Pours a medium gold/light amber coloration with a medium, fizzy head. Smell is quite hoppy, with light biscuity malt. Notes of citrus/tropical fruit, with orange and tangerine dominating. Lighter notes of grapefruit and mango. Taste follows the nose, with strong, hoppy citrus fruit, lighter tropical fruit and some biscuity malt. Nice citrus character dominated by orange, tangerine and grapefruit, with just a hint of mango. Very light dank, grassy, herbal notes in the background as well. Finishes with a light bitterness, mild hop burn and a little more dankness coming through in the aftertaste. Medium body and carbonation. Not sure if it quite lives up to the hype, but a very nice citrus Pale Ale with light notes of tropical fruit and dankness.
#
# 4.94
# POUR: Pint can into a nonic pint. APPEARANCE: Hazy golden orange in color. White head that is more of a film. Sticky and moderate glass lacing. Good looker. AROMA: Hoppy citrus on the nose. Also picking up some juicy mango. Great Citra hop profile. TASTE: Light and delicate. Crushable. Taste follows nose but also reveals some biscuit malt. Some dank and juicy elements come through as well on the exhale. AFTERTASTE: Flavors of Citra hops last throughout and reveals some nice malty flavors. Slight bite on the backend but nothing too serious. NOTES: Easy drinker and good looker. Crushable and well crafted. REVIEW/RATING: Excellent/ 5 out of 5.
#
# 4.51
# This is certainly one of the highest-rated APAs on BA, and it's one I've wanted for a long while. Thanks to TG's expansion into the MA market, I hope to be able to pick it up fairly regularly because... it's awesome! I'm not surprised, but it's always good to feel vindicated for personal high hopes based upon the BA community's reverence for a particular brew. In other words: when something lives up to the BA hype, I become further convinced this is the very best beer community on the Internet! This pours an insanely hazy, nearly-opaque orange color with a dollop of creamy head that seems to last for quite a while before sinking to approximately a finger-and-a-half in my glass. It leaves behind solid lace and some sticky, inconsistent lace. The surface is almost fully-obscured, with some bubbles congregating in small pockets. From what I can tell, this bears a fair-moderate carbonation, but the streams are not easy to notice considering the haze. The nose here is wonderfully dank and citrusy with moderate notes of sweet tropical fruit, ranging from ripe mango to papaya and passion fruit. Super juicy smelling with complementing pine resin and dank, grassy, green elements that really shock my senses. As soon as I opened this one, I had to put my nose to the aluminum can to deeply inhale and indulge in the aroma I knew this would produce... my response was no less than an audible proclamation of "fuuuuck," and I knew I would be in good hands. The flavor is chock-full of ripe citrus and mango, with flashes of dankness and slight green onion. Grapefruit rind and papaya crossed with unfiltered/pulp-laden orange juice washes over the palate, providing waves upon waves of intense juicy hop goodness. The malt profile seems slightly dextrin-heavy, keeping things firmly planted on the heavier-bodied side of the APA style (this drinks more like an XPA/Extra Pale Ale than an APA... kind of between an APA and IPA in bitterness/flavor/feel), lending a bit of biscuity malt backbone betwixt the intense hop throwdown. Carbonation is rather steady, with a finish that leans dry and chalky with a bit of extra hop pellet goodness. However, it borders on astringent and definitely sips more like an IPA than a traditional, easier-drinking APA, but I'll give it a pass because it's just so damn good. If I can get this fresh and often, I absolutely will. So good to finally be able to have a beer I've only been able to read about for years!
#
# 4.37
# Drank from a 16 oz/1 pint can purchased at Yankee Spirits, Sturbridge, MA Served in a tulip Hazy, yellow ochre appearance. The body was topped by a frothy, finger-tall, off-white crown that quickly fell to swirling wisps and a small halo. Some streaky arcs of lacing trickled down the glass. The aroma was really hoppy and pure. A dank, weedy quality was quite apparent initially but subsided within a few minutes. Juicy citrus notes took over. Orange and tangerine came through strongest. There was a subtle sweetness as well. A touch malty and honey-ish. Tropical fruits were also detectable. Mango and papaya perhaps. The tropical fruit notes intensified as the beer warmed. The flavor profile was also very citrus forward but definitely not as complex as the nose. Juicy orange and tangerine notes dominated. Bit of honey-like sweetness in the center. More orange and orange peel on the back end and in the finish. Just a hint of rind-like bitterness. Notes of candied orange peel lingered after the swallow. The mouthfeel was frothy and fluffy. Medium bodied for the style. The liquid contained a fine, fairly zippy, tongue blanketing effervescence. PseudoSue is a terrific, citra hopped American pale ale. That said, I am not quite sure it impresses most people these days in the way that it once did. With all the amazing hoppy beers available now in my region, I am curious to see how desirable Toppling Goliath’s pale ales and IPAs will remain over time.
#
# 3.94
# Sought this out after seeing how highly rated it was. Didn't really read the reviews, probably should have. Looks great, lively carbonation, slight hop haze, fluffy and persistent white head. It's basically a model for what a pale ale or lighter IPA should look like. The nose is bursting with juicy citra notes. It's got mango and tropical fruit with a hint of what reminds me of raspberries. Hard to even pick up much malt, and a whiff of alcohol sweetness. Some sweet dankness is in there too. Taste follows suit with a big ol smack of mangos, some dankness. Lively tropical fruits dominate with hardly any malt presence at all. Bitterness is noticeable, but restrained. Probably a little more bitterness than one would expect from most Pale Ales. Reminds me at times of Alpine Duet or Sculpin back when Ballast point was small. It's good, quite good, but it's an IPA. Look man, I get it, hops are the shit, IPA's rule, turn the flavor up to 11. But when I reach for a pale ale, I'm not looking for hop bombs. This beer is very unbalanced to me. I like some malt presence in my pale ales. Sierra Nevada Pale Ale is still far and away the reigning champ in pale ale world for me. Maybe I've just stopped enjoying hops as much as I've been over saturated with that flavor. Idk. I get why people like this beer, but I would rate it more highly if it were called an IPA. That's just me. Also, alcohol is fairly noticeable for the abv. Bottom line if you want a lighter, lower IBU IPA, that kicks you in the mouth with juicy citra mango and tropical fruit flavors, then this is your jam!
#
# 4.33
# Pours a nice deep gold, light orange with a nice white head that fell to a thin cap. Left decent lacing as I sipped. Smell is dank, pine, tropical fruit, fresh citrus. It's a powerful aroma that you get immediately upon popping the can open. Taste follows the nose with the fresh fruits and pine. There is some sweetness up front letting you know that the malt is there under all the hop flavor, but the hops definitely control this APA. There's a nice bitterness there too that reminds me of "old school" APA's. A hoppy aftertaste remains behind. The feel is rather soft, pleasant, and approachable. The carbonation is light but noticeable. It also finishes pretty dry. Overall, this is a really nice pale ale. At 5.2% ABV it's also very drinkable. It's a refreshing beer that I could see being a standard regardless of season.
#
# 4.34
# DATE: July 27, 2019... OCCASION: this is Take Three of this review--the first was cut short courtesy of the Point Pleasant power outage, while the second ended when my phone died....this one will be completed from my in-laws' location... GLASSWARE: (newly found) Hop Devil nonick... this pours as it did at 21st Amendment, with a frothy, off-white head that settles into a clumpy smear of sponge... its body, a stern medium brown amber, is replete with effervescent bubbles--exciting, considering its October 29th born-on date... intense grapefruit, mango, lemon grass, orange, dank basement and vegetable, thick resin, sweet and rich malts, sunflower and lilac--this ale is pale in name only, as its varied and voluminous aroma invigorates the drinker... wow, this has a creamy, chewy middle, a sharp, attacking entrance, and a smooth and dry finish--a complete, satisfying experience that refreshes and rewards without weighing me down, especially at 5.2% ABV, a crushable size for a pale ale... the mango, grapefruit and lemon grass are immediate and powerful... the resin is dank, thick and earthy, basement-worthy in its atmosphere.... toasted, crisp cracker malts and flowery esters make the experience even more complex and varied... honey, light spice, hoppy and balanced enough to be considered trying... having passed this over before--so many beers, so little time!--I rewarded myself with this, and it indeed is a reward, a citrusy, dank, chewy beer that becomes creamier as it drains... I plan to seek out out other Half Acre products, for sure...
#
# 4.25
# A really solid pale ale. Well balanced. Caramel and toasted grains blend with piney hops that are somehow both dank and bright. Fairly crisp, dry finish leaves me refreshed and ready for the next sip. Glad I finally picked up some cans of this one. Definitely worth another round!
#
# 3.86
# Appearance: Pours a medium neon orange color with a large, sticky and lazy head. Aroma: Strong citrus hop notes. Lots of orange, ripe pineapple, a little apricot. Very light and piney. Not too dank. Taste: Lots of orange citrus, ripe pineapple, and floral flavors. Strong pine and some pepper, yet finishes balanced and sweeter, less bitter than an IPA. One person describes the flavor as orange marmalade and I would agree. Feel: Incredibly smooth. Medium carbonation. Medium bodied. Leaves a pleasant honey flavor on the tongue with a mild pine bitterness underneath. Overall: Very smooth and well-balanced pale ale. Orange flavored, light floral and piney. I couldn't pick this one from a pack, but it's enjoyable and rounded as a pale ale should be.
#
# 3.79
# A wonderfully hoppy and bitter APA with IPA levels of hopping. Modern IPAs have perhaps passed this one by a little bit; I would imagine when it came out, it was ground-breaking, and the ratings appropriately reflect that. Bitter, moderately dank, floral, and bright. Less malt presentation than I would expect for an APA. Very lively and drinkable - almost crushable, if you didn't want to savor the notes.
#
# 3.65
# 16oz can from Wee Beer Shop, Glasgow (£4.50): A nice beer from Half Acre but definitely an underwhelming one too, the beer opened with a slightly dank nose that got me excited but beyond that it was mainly caramel &amp; biscuit that came through with the aroma, there was the odd tropical note further on but these seemed relatively subdued. The taste was again lacking that burst of pine, citrus or tropical fruits that I'd expected despite the fact that all three feature, it's just that all three seemed less pronounced than I'd have liked with the biscuit flavours coming through in equal measure with them. It was a drinkable &amp; enjoyable beer but I'd been expecting a lot more from this one only for it to turn out to be a fairly average offering in the end.
#
# 4.13
# 16 ounce can in a stemmed tulip glass. Translucent orange color. White fluff, 1F, fades to a film and leaves wavy ring lacing. Mango and other tropical fruit. Pine, damp and dank. A little citrus and a little malt. Tropical fruit flavor mix. More mango and a bit of pineapple. A dash of lemon citrus. Lightly caramelized pale malt. Enough malt to carry the body just past light in feel. Resinous. Hop bitterness and an incredibly dry finish.  Aromatic, flavorful, bitter, and easy drinking - all at 5.2% abv. Nice!
#
# 4.26
# Canned 4/13/18, consumed 5/5/18 L: Clear honey color with a nice big head that left nice bands of lacing. S: Terrific, full, danky, piney, and citrusy. If you like danky Simcoe, this had to be one of the best pale ale aromas out. T: Not as bright, balanced, and terrific as the aroma, but still solid all around. More danky and resiny hop flavors. F: Medium-light, slightly thin, strong solid bitterness, great lively carbonation. O: This is the first beer I've ever had from Half Acre, and I'm extremely impressed. Drinks like a solid, flavorful West Coast IPA but it's basically session-level ABV. Really glad to find fresh HA distributed out here, can't want to try more of their offerings.
#
# 3.39
# Canned on 1/25/18. 16oz can poured into a tulip. Pours golden with a subtle haze; fluffy white head that falls leaving great retention and nice lacing. The aromas are on the mild and subtle. Mild floral and citrus. Lots of bread, crackers and malts. It doesn't smell bad, it just doesn't really have much going on at all. The flavors are clean, crisp and refreshing. More floral notes along with some hints of grapefruit. Lots of fresh grass. More fresh bread and crackers. Moderate to low bitterness. Not much hop flavors going on. Malts do their thing. Alcohol goes unnoticed. Mouthfeel is nice. It's medium-bodied with moderate to active carbonation. It's very fluffy, smooth and easy to drink. This is a solid pale ale. It's a good classic and traditional example of the style, but it's definitely not "chock-full of dank, aromatic hops". I guess I was expecting something more "flashy" based on all of the love I've seen it receive forever.
#
# 4.11
# Pours a chill haze golden amber with a nice white head with decent retention. Smell is of citrus and grainy malt. Taste is citrus, lemongrass, a bit of dank, a touch of tropical fruit, with a lasting bitter finish. Refreshing and easy to drink without feeling too thin. I enjoyed this one a lot, one of the better pale ales I’ve had. I can see why this is a classic.
#
# 4.21
# 16oz globe glass. Honey colored, sticky lacing. Smells of mild citrus across the board and mild malts. Tastes of mild hops and a puff of citrus flavors, and a great dank aroma/taste. Low carbonation, low bitterness.. very smooth. This is a great tasting PA, and I always grab some of them when they are available.
#
# 4.23
# CAN Sticky snow cream over hazy brass. 4 Orange rind, sugared grapefruit, and dank. 4 Thread of cracker and Children’s Bayer to start, slight toffee, a bit dirty, blooms into big papaya, lemondrop, grass, and flowers, then tight lemon rind bitter leave. 4.25 Scratchy linger.  Light, oily, round. 4.25 11.16 canning, 12.21 drinking. When it’s cold, it comes across thin and underhopped - APAs suffer compared to Session IPAs these days. But it thickens up as it warms, and the lean citrus opens into resin and a ton of orange - an Amarillo fest. Weedy edge to the hopping, smooth enough, crisp - this is also doing a lot of details right that other beers don’t notice, especially at just ~5%.  A shifty, faceted old-school pale ale that rewards repeated visits. 4.5
#
# 4.25
# ...
#
# 4.19
# Drank from a 22 fl oz (1 pint 6 fl oz) bottle purchased at Cambridge Wine &amp; Spirits, Cambridge, MA Bottled on 04/10/18 Served in a tulip Completely opaque, glowing yellowish-orange appearance. Much cloudier than the original PseudoSue I recently drank from a can. The turbid body was topped by a frothy, half-inch tall, bright white crown that fell to a thick, lasting collar. Odd shaped splotches of lacing stuck along the glass. The aroma was uber hoppy and fruity. Loads of citrus. Big freshly squeezed orange juice presence. Mango was also quite noticeable. Touch of honeydew melon. Bit of dank cannabis too. As the beer warmed, the cannabis notes really intensified. Skunky weed came to mind. Overall, really punchy and super smooth. The flavor profile was also very hoppy and fruit forward, but fairly bitter and slightly astringent as well. Grapefruit dominated. White grapefruit specifically. The Galaxy hops definitely made their presence known here. Tangy clementine and kumquat notes were also apparent. Subtle honeydew melon-like quality in the center. More grapefruit and grapefruit rind on the back end and in the finish. Super pithy and dry. Big, bitter, grapefruit rind and pine resin notes lingered after the swallow. With time, the bitterness mellowed out slightly. Medium-light bodied mouthfeel. Creamy, slick and smooth. The liquid contained a fine, moderate effervescence that frothed up nicely on the palate. Galaxy Dry Hopped PseudoSue is a punchy, fruit-forward and overall really interesting take on a New England-style pale ale. Like the original PseudoSue, however, this beer turned excessively pithy and bitter on the finish. With a bit more balance, this could be stellar.
#
# 3.99
# Got a growler. The taste/smell follow the other reviews for me. I got a lot of carbonation in mine. Turned to foam almost instantly when it hit my tongue.... notably “danker” than normal pseudo sue. Would like to try another bottle.
#
# 4.24
# Bottled 17 days ago.  L — Pours a hazy golden orange with a finger of dense white head produced with moderately aerated pour. Noticeably more hazy than regular PseudoSue, this looks more akin to Trillium’s Fort Point variants. Some retention and good lacing S — Has that characteristic Galaxy dankness. Pineapple, grapefruit, green onion, mango, papaya, and a hint of diesel meld nicely with a soft creamy yeastiness. Reminds me of In Perpetuity from Tree House  T — Beer takes a bit of an unexpected turn here. Starts with a woodsy kick followed by green onion and mild tropical fruits contributed by the Galaxy dry hop. Then the citra comes in with a burst of orange zest, strawberry, and grapefruit. Finishes with a moderate bitterness and astringency  F -- A bit thin and lacking in dimensionality. Medium- mouthfeel, medium carb. Still decent, though. A little less sweet than regular PseudoSue, which is good O -- This may be the first galaxy/citra pale I've had and I have to say it's a bit of an odd combo. Nevertheless it's a joy to drink. I feel like a broken record in my reviews of TG's bottled hoppy offerings, but once again the $12/bomber pricing just doesn't work. Probably the reason my local store in MA has their bombers sitting around for weeks, and that's after only two distributions to the state, ever!  85/100
#
# 3.84
# Hazy burnt yellow with a very large, fluffy uneven foam settling in fits and starts, leaving pockmarked rows of lace. Smell is very cannabic, dank and resinous--this is ultra cannabis--spritzed by orange and grapefruit, with hints of biscuity cracker. It gets less cannabic with time. Taste is tangy citrus with hints of Sweet Tarts, paired with less potent but still present dank cannabis, finishing with a biscuity swallow, and cracker in the aftertaste. It gets softer and more biscuity as it warms. Medium-light body, almost watery actually, but for a thin, crisp but weak fizz and a semi-dry finish.
#
# 4.53
# poured from a bomber dated 2/12/19 into a pint glass. pours a very murky &amp; milky dark golden yellow. nice, fluffy bright white head. smells as fruity as regular sue but with more dank hop aroma. taste is quite juicy. nice rush of hops and tropical fruits. feel is damn near perfect. full bodied and somewhat low on the carbonation. overall a deliciously flavorful and absurdly drinkable pale ale.
#
# 3.87
# Cloudy, almost murky with a light peach colored appearance. Wispy two finger head that disappears quickly. Reticent nose - with swirling some piney, dank, earth-like aromas appear with a bit of cracker. Palate is very dry with pine and earth. Don't get any tropical flavors that I was expecting. Feel is in line with what you'd expect from a pale - lighter with good carbonation. Pretty good DDH Sue version though I much prefer the Mosaic or Citra versions to this.
#
# 4.3
# Hazy peach color with off-white head. Aroma is bright and hoppy with intense ripe stonefruits, dank notes, grass. Taste starts with sweet stonefruit, some pineapple but gets more bitter and dank towards the finish. Medium body with medium to low carbonation, really easy to drink. Really well made and aromatic pale ale.
#
# 4.16
# Very much like the original PseudoSue but with the dank citrus notes characteristic of galaxy hops. A little too dank for me, to be honest-- the earthy musk doesn't really do it for me, but nonetheless, a beer that showcases the hop well and drinks like I would expect a TG APA to drink. A great beer, for sure! Recommended.
#
# 4.44
# Bomber. Pours hazy orange, finger white head lasts leaving coating lace. Juicy aroma with dank hops present. Taste of bready sweetness offset by citrus and piney hops, so well balanced. Finishes dry with a soft creamy mouthfeel. Excellent pale ale.
#
# 4.17
# Pours a slight hazed golden color with a frothy white head and very nice sticky lacing. Smell is dank earthy hops with with citrus and tangerine some white fruit hops. Taste is is ripe tropical and citrus fruit with some dry bitter pine mixed in a sweet malt balances out the hops. mouthfeel is light and creamy but has a dry finish, highly drinkable
#
# 4.06
# It pours golden with a slight haze and about two fingers of head. The aroma is dank and piney. The taste is fairly balanced but the finish is fairly lopsided on the bitter side. Medium body and not much in terms of carbonation bite.
#
# 4.01
# Got in a trade with The-Adjunct-Hippie. 16 ounce can into pint glass, canned on 7/20/2017. Pours slightly hazy/cloudy deep golden/yellow color with a 2 finger fairly dense and fluffy white head with great retention, that reduces to a large cap that lasts the whole glass. Thick foamy lacing clings down the glass, with a moderate amount of streaming carbonation retaining the cap. Fantastic appearance. Aromas of tangerine, grapefruit, peach, pineapple, passion fruit, papaya, mango, melon, berry, lemon zest, orange peel, light pepper/pine, honey, lightly toasted bread, herbal, and floral/grassy earthiness. Nice and pleasant aromas with good balance and complexity of citrus/fruity/tropical hops and moderate pale malt notes; with solid strength. Taste of big tangerine, grapefruit, peach, pineapple, passion fruit, papaya, mango, melon, berry, lemon zest, orange peel, light pepper, pine, honey, lightly toasted bread, herbal, and floral/grassy earthiness. Light-moderate pine, citrus peel, grassy, spicy bitterness on the finish. Lingering notes of tangerine, grapefruit, peach, pineapple, passion fruit, papaya, mango, melon, berry, lemon/orange peel, citrus rind, pepper, pine, honey, lightly toasted bread, and herbal/floral/grassy earthiness on the finish for a while. Awesome complexity, robustness, and balance of citrus/fruity/tropical hops and moderate pale malt flavors; with a great malt/bitterness balance, and zero lingering hop astringency after the finish. Light-moderate increasing dryness from bitterness. Medium-high carbonation and light-medium body; with a very smooth, moderately crisp, bready/grainy/sticky, and lightly resinous/rindy balanced mouthfeel that is great. Zero warming alcohol as expected of 4.7%. Overall this is an excellent American pale ale! All around great complexity, robustness, and balance of citrus/fruity/tropical hops and moderate pale malt flavors; very smooth, crisp, and refreshing to drink with the modestly bitter/drying finish. Nice mix of vibrant/dank hop character; with a nice malt backbone and body for the ABV. A very enjoyable offering.
#
# 4.15
# 16oz can poured into a globe. A: Deep golden color with a slight haze. Fine-bubbled white head retains well and leaves behind a thick collar of lacing. S: Kiwi, honeydew melon, juicy, tropical, lemon, hint of dankness, slightly floral. Doughy malt, light toast. T: Honeydew melon and kiwi up front. Lemon, earthy and dank flavors then take hold. Crackery and lightly toasty malt. Slight yeastiness. Bitterness is moderately stiff. Finishes quickly with some melon rind and dankness. M: Medium bodied. Full and creamy. Deep crispness thanks to the amole carbonation. O: Great pale ale. Mosaic and centennial are a brilliant combo- sort of old school and new. Very tasty, too easy to quaff back the 16oz can. Seek it out.
#
# 4.07
# Golden orange in color with a light haze. Poured with a moderate, creamy white foam with good retention. Medium dank, oniony and herbal hop aromas with medium light malt beneath. Medium light bodied with medium light carbonation and a light creamy feel through the middle. Medium high, fresh, spicy, herbal, oniony hop flavors up front followed by medium spicy hop bitterness through the middle. Spicy herbal hops follow to the end. Medium malt flavors from beginning to end. Finished semi-dryly with light malt and spicy flavors and a touch of bitterness. Fabulous hop aromas and well balanced malt and hop bitterness. Spicy bitterness through the middle plays well with the medium light carbonation. Great can art and much appreciated pint can format for this less than 5% abv offering. Very tasty and drinkable.
#
# 4.0
# Pours clear, gold in color with one inch head. Taste is grass, pale malt, light orange juice, and dank hops. Light bodied, dank, slightly bitter with moderate carbonation. Makes for a solid sessionable pale. There are other pales I prefer, but the dankness really sets this one apart. I would get it again.
#
# 3.85
# Had this on 2017-04-16 in Warrenville, IL from a 16oz canned on 2017-03-23 A - Lightly hazy with a 1-finger white head and light lace.  S - pineapple, grass, papaya and orange. Little to no grain.  T - Ripe pineapple, orange, lightly dank, cracker, pine. Restrained bitterness. M - Light body and light-medium carbonation. Smooth then dry.  O - Not as forward in aroma or flavor as Daisy Cutter. This is an easy, hot summer day, session IPA.
#
# 4.38
# 16oz pint at Olympic tavern Half acre tap takeover. Appearance: Opaque golden body with white head. lots of lacing left behind after each sip.  Smell: clean orange sweet citrus nose with light catty and dank hops. Fruity and floral. Hint of grass. Really nice hop profile in this pale ale. Hint of light bready malt. Taste: Much similar to the nose. Lots of sweet orange citrus notes and a hint of catty dankness. Light bitterness from the hops. Fruity and floral. A nice juicy quality from the hops that is reminiscent of top tier east coast hoppy beers.  Mouthfeel: On the lighter end of a medium bodied beer or the high end of a light beer. Which ever you think is more accurate. Moderate carbonation levels with a creamy carbonation noted. Feels juicy and wet while still being flavorful and sessionable. Overall: This is definitely my favorite beer from Half Acre; it is easily better than daisy cutter and double daisy cutter. Haven't seen this on the shelf before, but one thing is for sure that this would be a fantastic hot weather beer come summer time especially drinking it from a tallboy. Really nice combo of hops and the fact that it reminds me of east coast hoppy beers with that awesome juicy hoppyness character really put this over the top. This is a local gem!
#
# 3.74
# Pours a hazy straw out of the can with a decent white head that slowly settles. This is a hopped up APA with a light malt base. Smells lime, grapefruit, tangerine, some herbal, dank, grassy, a bit sweet, some caramel. Tastes of pungent but not very bitter hops with characteristics of grapefruit rind, lime, tangerine, some grass and earth, some dank, a little tobacco, along with bready malt and light caramel seeetness. Finish is on the bitter side. It does not linger. Solid.
#
# 3.88
# Great beer. Golden pour with a huge light-as-air head. Lots of pine and some orange rind on the note. Smells crisp and refreshing with a touch of dank hops. Taste is grapefruit, pine, fresh cut grass and a little lemon zest. Finishes clean and surprisingly dry - real easy on the palette. Great example of a west coast brew. So glad to try it.
#
# 4.57
# 16 oz. canned on 07/19/16 Pours foggy hazy straw gold with a large creamy white foam head. Smells like fresh grapes, gooseberry, passionfruit, guava, pineapple, grapefruit, orange citrus, nutty crackery bready caramelized malt, with woodsy earthy herbal grass and dank spicy pine. Tastes like grapes, gooseberry, pineapple, passionfruit, guava, grapefruit, orange citrus, some nutty crackery bready caramelized malt, with woodsy earthy herbal grass and dank spicy pine. Feels medium bodied, creamy and smooth with moderate low carbonation. Overall a really nice pale ale.
#
# 4.22
# 1 month since canning The beer pours a clear straw yellow topped by memory-foam-like white head that fades with creamy lacing. The nose is dank with hops - grassy, some light citrus, and a hint of savory (garlicy/chives) hops as well- but it's still a bit grainy and bready. The taste has a soft grain presence, grassy and savory hops, a bit of white tea that lingers on the palate, and minimal alcohol or yeast.This is a very light bodied, sessionable APA with a striking balance between hop potency and drinkability. If you've had hoppy MT joints in the past, you know what to expect, but if not, this highly drinkable and potently hoppy APA doesn't disappoint.
#
# 4.05
# Fresh can into a teku at fridge temp. Look: super clear pale straw, sudsy head, good carb. Smell: strong herbal/spice note—something like parsley, maybe. Also some tangy lemon/lime. Intriguing. Taste: the spice note comes through as something dank and funky in the taste. Some mild crackery malt. Not much else. Feel: light and generally unoffensive. Overall: this is a pretty simple beer, bordering on hop-water. The aroma and flavor are interesting (presumably courtesy of the experimental hop). On a side note, I'd love to see how this hop played in a saison—I think the spice character would complement the pepper/funk and produce magic.
#
# 3.94
# Pale yellow, hazy brew topped with a very fluffy snow-white head. Good retention and wide, thin fields of lacing. Lots of center-glass carbonation. Big hop aroma immediately upon uncapping. Bright, indistinguishably fruity hops; light dank sweetness, tobacco, and earth; honey; straw; light caramel and bready malts. Light but full-flavored, sweet, and incredibly dank on the mid- and back-end. Vague tropical fruits, honey, biscuit and bread, tobacco. Surprisingly medium bodied, not quite chewy, but still drinkable. No sting, not particularly lively, but not flat either. Easily the most full-bodied and flavorful "session"-level APA or IPA I've had. I'm not 100% on board with the hop profile, but it gives it a huge, interesting kick, and is well-worth seeking out, especially for fans of Mosaic and Citra hops (of which this beer is reminiscent).
#
# 4.01
# A- Pours a slightly hazy pale gold with a thin white head. Some light spotty lace. S- Piny and dank on the nose with some grapefruit pith, pine sap, and mint. T: Similar to the smell. A good pony hop bite with some grainy malt in the back. Some floral notes and a good drawl of resin on the finish with just a touch of bready malt holding it in check. Not out of this world, but a good pale.

# %% [markdown]
# ### Random Forest

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
vec = Vectorizer(to_vec = "review")
model = RandomForestClassifier(n_estimators=100)

#Setting up pipeline
for_pipe = Pipeline(steps = [("dropper", dropper),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
for_pipe.fit(X_train, y_train)
scores = cross_val_score(for_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(for_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.751
# CV std = 0.009
#
# Test score: 0.757

# %%
for_import = pd.DataFrame(zip(for_pipe.steps[1][1].feature_names, for_pipe.steps[2][1].feature_importances_), columns = ["feature", "importance"])

# %%
for_import.sort_values("importance", ascending=False).head()
# Out:
#      feature  importance
# 8224   great    0.008198
# 5044  decent    0.007551
# 8589    head    0.007282
# 1698     bad    0.006758
# 3743  citrus    0.006153

# %% [markdown]
# ### Stemming Logistic

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs")

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             ("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
log_pipe.fit(X_train, y_train)
scores = cross_val_score(log_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.769
# CV std = 0.005
#
# Test score: 0.774

# %%
log_coeffs = pd.DataFrame(zip(log_pipe.steps[1][1].feature_names, log_pipe.steps[2][1].coef_[0]), columns = ["feature", "coeff"])
log_coeffs.sort_values("coeff", ascending=False).head(10)
# Out:
#              feature     coeff
# 82975           nice  5.271739
# 56435          great  3.341485
# 9443        balanced  2.916788
# 54626           good  2.507252
# 104393       session  2.293725
# 24044           cask  2.251237
# 26362         citrus  2.187216
# 43185      excellent  2.183246
# 108486        smooth  2.020351
# 104403  session beer  1.788776

# %% [markdown]
# ### Finding best C for logistic

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegressionCV(solver = "lbfgs", Cs=20, cv=5, max_iter=1000)

#Setting up pipeline
logcv_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
logcv_pipe.fit(X_train, y_train)

print("Train score: {0:.3f}".format(logcv_pipe.score(X_train, y_train)))
# Out:
# Train score: 0.864

# %%
logcv_pipe.steps[2][1].C_[0]
# Out:
# 0.8286427728546842

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs", C=0.8286427728546842)

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
log_pipe.fit(X_train, y_train)
scores = cross_val_score(log_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.751
# CV std = 0.014
#
# Test score: 0.754

# %%
log_coeffs = pd.DataFrame(zip(log_pipe.steps[1][1].feature_names, log_pipe.steps[2][1].coef_[0]), columns = ["feature", "coeff"])
log_coeffs.sort_values("coeff", ascending=False).head(20)
# Out:
#           feature     coeff
# 5210        great  3.433925
# 7538         nice  3.185744
# 1060     balanced  2.545962
# 4210    excellent  2.479719
# 5126         good  2.304788
# 2966        crisp  1.691999
# 12471   wonderful  1.538273
# 9833      session  1.518206
# 1346     biscuity  1.506604
# 9354         rich  1.481384
# 5515       herbal  1.479261
# 11177       tasty  1.460185
# 1216        beers  1.430791
# 2041         cask  1.427855
# 6703         love  1.418187
# 10293       solid  1.401057
# 3737    drinkable  1.390572
# 8257      perfect  1.290577
# 4821        fresh  1.257875
# 9114   refreshing  1.257139

# %% [markdown]
# ### Trying gridsearch (no real luck)

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs", C=0.8286427728546842)

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

log_params={"vec__min_df" : [1, 0.02, 0.05],
            "vec__max_df" : [1.0, 0.9, 0.95],
            "vec__ngram_range" : [(1,1)],
            #"stem__style" : [None, "porter", "lancaster"],
            "model__C" : np.logspace(-3,0,10),
            "model__solver" : ["newton-cg", "saga", "sag"],
            "model__penalty" : ["l2"]}

log_gs=GridSearchCV(log_pipe,
                    log_params,
                    n_jobs=-1,
                    cv=3,
                    verbose=10)

#Fitting and scoring model
log_gs.fit(X_train, y_train)

scores = cross_val_score(log_gs.best_estimator_, X_train, y_train, cv=5)
print("GS score: {0:.3f}".format(log_gs.best_score_))
print("")
print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_gs.best_estimator_.score(X_test, y_test)))
# Out:
# Fitting 3 folds for each of 270 candidates, totalling 810 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 499 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 500 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 501 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 502 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 507 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 509 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 510 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 513 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 515 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 516 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 517 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 518 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 519 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 523 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 524 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 525 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 526 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 527 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 531 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 532 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 533 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 534 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 535 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 536 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 540 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 541 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 542 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 545 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 547 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 548 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 549 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 550 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 551 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 553 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 554 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 555 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 557 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 559 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 560 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 561 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 562 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 563 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 564 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 566 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 567 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 569 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 571 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 572 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 574 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 575 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 576 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 578 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 579 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 581 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 582 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 583 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 585 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 586 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 587 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 588 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 589 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 590 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 591 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 592 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 593 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 594 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 595 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 598 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 599 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 600 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 601 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 603 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 604 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 606 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 609 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 611 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 612 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 613 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 614 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 615 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 617 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 618 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 619 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 620 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 621 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 622 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 623 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 625 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 626 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 627 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 628 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 629 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 630 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 631 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 633 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 634 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 635 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 636 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 637 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 638 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 639 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 641 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 642 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 643 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 646 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 647 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 651 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 652 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 653 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 654 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 655 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 657 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 658 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 659 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 660 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 661 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 662 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 663 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 665 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 666 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 667 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 668 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 669 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 670 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 671 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 673 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 675 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 676 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 678 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 679 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 680 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 681 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 683 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 684 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 685 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 686 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 687 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 689 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 690 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 691 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 692 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 694 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 695 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 697 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 698 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 699 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 700 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 701 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 702 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 703 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 704 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 705 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 707 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 708 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 709 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 710 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 711 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 712 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 713 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-1)]: Done 715 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-1)]: Done 716 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-1)]: Done 717 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 718 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 719 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 720 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 721 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 722 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 723 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 724 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 725 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 726 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 727 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 728 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 729 tasks      | elapsed: 19.6min
# [Parallel(n_jobs=-1)]: Done 730 tasks      | elapsed: 19.6min
# [Parallel(n_jobs=-1)]: Done 731 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 732 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 733 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 734 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 735 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 736 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 737 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 738 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 739 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=-1)]: Done 740 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=-1)]: Done 741 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=-1)]: Done 742 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 743 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 744 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 745 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 746 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 747 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 748 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 749 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=-1)]: Done 750 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=-1)]: Done 751 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 754 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 755 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 756 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 757 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 758 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 759 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 760 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 761 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 762 tasks      | elapsed: 20.3min
# [Parallel(n_jobs=-1)]: Done 763 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 764 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 765 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 766 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 767 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 768 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 769 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 770 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 771 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done 772 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done 773 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done 774 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 775 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 777 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 778 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 779 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 780 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 781 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 782 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 783 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed: 21.0min
# [Parallel(n_jobs=-1)]: Done 785 tasks      | elapsed: 21.0min
# [Parallel(n_jobs=-1)]: Done 786 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 787 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 788 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 789 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 790 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=-1)]: Done 791 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 21.3min
# [Parallel(n_jobs=-1)]: Done 793 tasks      | elapsed: 21.3min
# [Parallel(n_jobs=-1)]: Done 794 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 795 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 797 tasks      | elapsed: 21.5min
# [Parallel(n_jobs=-1)]: Done 798 tasks      | elapsed: 21.5min
# [Parallel(n_jobs=-1)]: Done 799 tasks      | elapsed: 21.5min
# [Parallel(n_jobs=-1)]: Done 800 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done 801 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 802 tasks      | elapsed: 21.8min
# [Parallel(n_jobs=-1)]: Done 803 tasks      | elapsed: 21.8min
# [Parallel(n_jobs=-1)]: Done 810 out of 810 | elapsed: 22.0min finished
# GS score: 0.750
#
# CV score: 0.750
# CV std = 0.016
#
# Test score: 0.753

# %%
log_gs.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('dropper',
#                  Dropper(to_drop=['look', 'smell', 'taste', 'feel', 'overall',
#                                   'date', 'id', 'name', 'rating'])),
#                 ('vec',
#                  Vectorizer(max_df=1.0, min_df=1, ngram_range=(1, 1),
#                             stop_words='english', to_vec='review')),
#                 ('model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='newton-cg', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# ### Trying SVC

# %%
from sklearn.svm import SVC

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = SVC(gamma="scale")

#Setting up pipeline
svc_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
svc_pipe.fit(X_train, y_train)
scores = cross_val_score(svc_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(svc_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.748
# CV std = 0.016
#
# Test score: 0.750

# %% [markdown]
# ### Trying a higher split

# %%
apa_df.describe()
# Out:
#             rating         look        smell        taste         feel  \
# count  4874.000000  4874.000000  4874.000000  4874.000000  4874.000000
# mean      3.619532     3.754762     3.512302     3.612630     3.601705
# std       0.540676     0.527734     0.591372     0.630672     0.606153
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       3.320000     3.500000     3.000000     3.500000     3.250000
# 50%       3.680000     4.000000     3.500000     3.500000     3.500000
# 75%       3.980000     4.000000     4.000000     4.000000     4.000000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#            overall             id   rating_bin
# count  4874.000000    4874.000000  4874.000000
# mean      3.727731   21149.727329     0.558474
# std       0.658809   29841.591009     0.496620
# min       1.000000     222.000000     0.000000
# 25%       3.500000    2933.000000     0.000000
# 50%       4.000000   10144.000000     1.000000
# 75%       4.000000   27854.000000     1.000000
# max       5.000000  242866.000000     1.000000

# %%
#setting X and y, and creating split
X=apa_df.drop(columns = ["rating_bin"]).copy()
y = X["rating"].apply(lambda x: 1 if x >= 4 else 0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs", C=0.8286427728546842)

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
log_pipe.fit(X_train, y_train)
scores = cross_val_score(log_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.777
# CV std = 0.009
#
# Test score: 0.802

# %%
X["rating"].apply(lambda x: 1 if x >= 4 else 0).value_counts(normalize=True).max()
# Out:
# 0.7535904800984817

# %% [markdown]
# ### Going more in depth in the best model so far

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs", C=0.8286427728546842)

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
log_pipe.fit(X_train, y_train)
scores = cross_val_score(log_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.749
# CV std = 0.012
#
# Test score: 0.743

# %%
lr_predict = log_pipe.predict(X_test)

print(classification_report(y_test, lr_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.63      0.68       430
#            1       0.74      0.83      0.78       545
#
#     accuracy                           0.74       975
#    macro avg       0.74      0.73      0.73       975
# weighted avg       0.74      0.74      0.74       975

# %%
conmat = confusion_matrix(y_test, lr_predict, labels = [1,0])

pd.DataFrame(conmat,
            columns = ["p_high", "p_low"],
            index = ["high", "low"])
# Out:
#       p_high  p_low
# high     455     90
# low      161    269

# %%
y.mean()
# Out:
# 0.5584735330324169

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegressionCV(solver = "lbfgs", Cs=20, cv=5, max_iter=1000, verbose=5, n_jobs=-1)

#Setting up pipeline
logcv_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
logcv_pipe.fit(X_train, y_train)

print("Train score: {0:.3f}".format(logcv_pipe.score(X_train, y_train)))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 12.9min remaining: 19.3min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 15.3min finished
# Train score: 0.894

# %%
logcv_pipe.steps[2][1].C_[0]
# Out:
# array([1.62377674])

# %%
logcv_pipe.score(X_test, y_test)
# Out:
# 0.7405128205128205

# %%
#setting X and y, and creating split
X=apa_df.copy()
y = X.pop("rating_bin")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

#Setting up pipeline classes
dropper = Dropper(["look", "smell", "taste", "feel",
                    "overall", "date", "id", "name", "rating"])
stem = Stemmer(["review"], style="porter")
vec = Vectorizer(to_vec = "review")
model = LogisticRegression(solver = "lbfgs", C=1.62377674)

#Setting up pipeline
log_pipe = Pipeline(steps = [("dropper", dropper),
                             #("stem", stem),
                              ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
log_pipe.fit(X_train, y_train)
scores = cross_val_score(log_pipe, X_train, y_train, cv=5)

print("CV score: {0:.3f}".format(np.mean(scores)))
print("CV std = {0:.3f}".format(np.std(scores)))
print("")
print("Test score: {0:.3f}".format(log_pipe.score(X_test, y_test)))
# Out:
# CV score: 0.749
# CV std = 0.013
#
# Test score: 0.741

# %% [markdown]
# ### Trying out the model on brewers' descriptions

# %%
beers = pd.read_csv("./data/beers.csv")

# %%
beers["review"]=beers["desc"]
clean_beers = beers.dropna()

# %%
#setting X and y, and creating split
X=clean_beers[["review"]].copy()
y=clean_beers["av_rating"].apply(lambda x: 1 if x > 3.6 else 0)

#Setting up pipeline
new_pipe = Pipeline(steps = [ ("vec", vec),
                              ("model", model)])

#Fitting and scoring model
y_pred = new_pipe.predict(X)

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.07      0.10        14
#            1       0.71      0.84      0.77        38
#
#     accuracy                           0.63        52
#    macro avg       0.43      0.46      0.43        52
# weighted avg       0.56      0.63      0.59        52

# %%
conmat = confusion_matrix(y, y_pred, labels = [1,0])

pd.DataFrame(conmat,
            columns = ["p_high", "p_low"],
            index = ["high", "low"])
# Out:
#       p_high  p_low
# high      32      6
# low       13      1

# %%
clean_beers["rating_pred"] = y_pred
# Out:
# C:\Users\James\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,7):
    print(clean_beers[clean_beers["rating_pred"] == 0].iloc[i,10])
    print("")
# Out:
# This 4.2% Kentish ale (bottle 4.5%) was first brewed in 1990 to celebrate the Battle of Britain which was fought in the skies above Kent 50 years earlier. The beer is named after the legendary Spitfire aeroplane designed by RJ Mitchell. The versatility of the aircraft and the courage of its pilots were essential to victory and were a key symbol of the spirit of that time.
#
# The pint of pints. Belhaven Best is the main man of draught ales. Best colour, best flavour, best balance - the pint for all occasions. We Scots are often not known for blowing our own trumpets, modest souls that we are, but we've named this Best for a reason. We're sure you'll agree.
#
# 5.5% ABV 31 IBU'S
#
# A general term for what is perhaps the highest expression of the brewer's craft. Amber not filtered and true to style. A natural with fish and chips.
#
# Cwrw Braf is a clean-drinking, amber-coloured ale with a light bitterness and gentle hop aroma. A session bitter yet, with all the flavours and quality you would expect from a Tomos Watkin premium ale.
#
# A bright golden coloured best bitter formerly called Golden Eagle.
#
# We created this beer to celebrate the opening of The Porterhouse in Covent Garden, London, in July 2000. We brewed a traditional style pale ale with a modern interpretation using a single variety of New Zealand hop, the Sticklebract.
